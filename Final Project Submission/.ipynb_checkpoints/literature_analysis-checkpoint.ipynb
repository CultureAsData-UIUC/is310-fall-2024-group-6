# %% [markdown]
# # Exploratory Analysis of Children's Literature Over Time

# %% [markdown]
# ## Import Nessecary Libraries

# %%
import pandas as pd

import matplotlib.pyplot as plt

from scipy.interpolate import make_interp_spline

import numpy as np

# %% [markdown]
# Read in Dataset

# %%
df = pd.read_csv("dataset_final.csv")

# %% [markdown]
# Convert Publication Dates to numeric values over time

# %%
df['Data Published'] = pd.to_numeric(df['Data Published'].str.extract('(\d{4})')[0], errors='coerce')

# %% [markdown]
# Sort Data by Year

# %%
df = df.sort_values(by='Data Published')

# %% [markdown]
# Function to smooth lines

# %%
def smooth_line(x, y, num_points=300):
    x_new = np.linspace(x.min(), x.max(), num_points)
    y_smooth = make_interp_spline(x, y)(x_new)
    return x_new, y_smooth

# %% [markdown]
# Drop missing values and Drop Duplicates

# %%
df = df.dropna(subset=['Data Published', 'Polarity', 'Subjectivity'])

# %% [markdown]
# Polarity and Subjectivity by Book Title

# %%
plt.figure(figsize=(12, 8))
df.plot(kind='bar', x='Book Title', y=['Polarity', 'Subjectivity'], figsize=(12, 8))
plt.title("Polarity and Subjectivity by Book Title")
plt.ylabel("Scores")
plt.xlabel("Book Title")
plt.xticks(rotation=45, ha='right')
plt.legend(["Polarity", "Subjectivity"])
plt.tight_layout()
plt.show()

# %% [markdown]
# Polarity over time

# %%
plt.figure(figsize=(12, 8))
df.dropna(subset=['Data Published']).plot(kind='line', x='Data Published', y='Polarity', marker='o', figsize=(12, 8))
plt.title("Polarity Over Time")
plt.ylabel("Polarity")
plt.xlabel("Year Published")
plt.grid()
plt.show()

# %% [markdown]
# Subjectivity over time

# %%
plt.figure(figsize=(12, 8))
df.dropna(subset=['Data Published']).plot(kind='line', x='Data Published', y='Subjectivity', marker='o', figsize=(12, 8))
plt.title("Subjectivity Over Time")
plt.ylabel("Subjectivity")
plt.xlabel("Year Published")
plt.grid()
plt.show()

# %% [markdown]
# Subjectivity By Genre

# %%
# Analyze subjectivity by genre
genre_subjectivity = df.groupby('Genre')['Subjectivity'].mean().reset_index()

# Plotting the relation between Genre and Subjectivity
plt.figure(figsize=(12, 8))
plt.bar(genre_subjectivity['Genre'], genre_subjectivity['Subjectivity'], color='skyblue')
plt.title("Average Subjectivity by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Subjectivity")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Polarity by Genre

# %%
# Analyze polarity by genre
genre_polarity = df.groupby('Genre')['Polarity'].mean().reset_index()

# Plotting the relation between Genre and Polarity
plt.figure(figsize=(12, 8))
plt.bar(genre_polarity['Genre'], genre_polarity['Polarity'], color='lightgreen')
plt.title("Average Polarity by Genre")
plt.xlabel("Genre")
plt.ylabel("Average Polarity")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
